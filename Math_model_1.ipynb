# %% [markdown]
# <a href="https://colab.research.google.com/github/kateh321/Mathproject/blob/main/Math_model_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
################################################################################
import tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
################################################################################
from keras import layers,utils
from keras.datasets import cifar100
from keras.models import Sequential,load_model
from tensorflow.keras.optimizers import Adam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint,ReduceLROnPlateau
from tensorflow.keras.models import Model
from tensorflow.keras.utils import load_img
from tensorflow.keras.layers import BatchNormalization, Dense, Dropout, Activation, Flatten,Conv2D,MaxPooling2D, MaxPool2D,Add, concatenate
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.utils import img_to_array
from numpy import expand_dims
################################################################################

# %%
# !wget -O PBC_dataset_normal_DIB.zip https://data.mendeley.com/public-files/datasets/snkd93bnjr/files/2fc38728-2ae7-4a62-a857-032af82334c3/file_downloaded
# Out:
# --2022-05-01 14:30:45--  https://data.mendeley.com/public-files/datasets/snkd93bnjr/files/2fc38728-2ae7-4a62-a857-032af82334c3/file_downloaded
# Resolving data.mendeley.com (data.mendeley.com)... 162.159.133.86, 162.159.130.86
# Connecting to data.mendeley.com (data.mendeley.com)|162.159.133.86|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com/5a5a3b1a-0b1d-46bc-bff2-0420599d351b [following]
# --2022-05-01 14:30:46--  https://md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com/5a5a3b1a-0b1d-46bc-bff2-0420599d351b
# Resolving md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com (md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com)... 52.218.52.251
# Connecting to md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com (md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com)|52.218.52.251|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 281366219 (268M) [application/zip]
# Saving to: ‘PBC_dataset_normal_DIB.zip’
#
# PBC_dataset_normal_ 100%[===================>] 268.33M  67.7MB/s    in 4.0s
#
# 2022-05-01 14:30:50 (67.1 MB/s) - ‘PBC_dataset_normal_DIB.zip’ saved [281366219/281366219]

# %%
# !unzip "/content/PBC_dataset_normal_DIB.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_292483.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_935950.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_890863.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_519370.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_215077.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_388154.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_968896.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_34345.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_349907.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_245683.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_785122.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_615525.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_714613.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_904757.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_38351.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_547436.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_824242.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_881832.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_345085.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_111336.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_247876.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_362412.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_554489.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_392939.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_291015.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_191913.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_878703.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_31605.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_394179.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_452211.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_780489.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_129326.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_683802.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_633119.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_380642.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_653606.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_852129.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_855646.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_756742.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_710065.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_506873.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_2429.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_840276.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_689453.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_5435.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_626298.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_779788.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_352063.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_23214.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_692098.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_871040.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_789137.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_206195.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_2158.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_226523.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_351768.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_555027.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_947900.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_762169.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_527499.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_297101.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_188099.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_602845.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_864908.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_428153.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_911429.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_426156.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_356198.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_471783.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_174418.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_338872.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_307328.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_367386.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_317661.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_793231.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_149216.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_50359.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_929405.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_217339.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_639541.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_864505.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_123030.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_307894.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_25063.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_215260.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_595149.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_137727.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_777158.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_62462.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_289065.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_797906.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_280069.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_360189.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_876139.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_372599.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_536180.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_37311.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_143717.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_43309.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_999467.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_986209.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_497955.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_451325.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_561580.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_849685.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_330594.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_682853.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_700663.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_617451.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_965569.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB_546922.jpg
#   inflating: PBC_dataset_normal_DIB/erythroblast/ERB
# Classes Length:  8

# %%
#Plotting sample images from dataset

x0 = plt.imread('PBC_dataset_normal_DIB/neutrophil/BNE_100878.jpg')
x1 = plt.imread('PBC_dataset_normal_DIB/eosinophil/EO_100213.jpg')
x2 = plt.imread('PBC_dataset_normal_DIB/lymphocyte/LY_461786.jpg')
x3 = plt.imread('PBC_dataset_normal_DIB/basophil/BA_100102.jpg')
x4 = plt.imread('PBC_dataset_normal_DIB/monocyte/MO_100695.jpg')
x5 = plt.imread('PBC_dataset_normal_DIB/erythroblast/ERB_508631.jpg')
x6 = plt.imread('PBC_dataset_normal_DIB/platelet/PLATELET_21481.jpg')
x7 = plt.imread('PBC_dataset_normal_DIB/ig/IG_101958.jpg')


fig, ax=plt.subplots(1,8)
fig.set_figheight(20)
fig.set_figwidth(20)


ax[0].imshow(x0)
ax[0].set_xticks([])
ax[0].set_yticks([])
ax[0].set_xlabel("Figure 1. NEUTROPHIL")

ax[1].imshow(x1)
ax[1].set_xticks([])
ax[1].set_yticks([])
ax[1].set_xlabel("Figure 2. MONOCYTE")


ax[2].imshow(x2)
ax[2].set_xticks([])
ax[2].set_yticks([])
ax[2].set_xlabel("Figure 3. LYPHOCYTE")

ax[3].imshow(x3)
ax[3].set_xticks([])
ax[3].set_yticks([])
ax[3].set_xlabel("Figure 4. EOSINOPHIL")

ax[4].imshow(x4)
ax[4].set_xticks([])
ax[4].set_yticks([])
ax[4].set_xlabel("Figure 5. BASOPHIL")

ax[5].imshow(x5)
ax[5].set_xticks([])
ax[5].set_yticks([])
ax[5].set_xlabel("Figure 6. Erythroblast")

ax[6].imshow(x6)
ax[6].set_xticks([])
ax[6].set_yticks([])
ax[6].set_xlabel("Figure 6. Erythroblast")

ax[7].imshow(x7)
ax[7].set_xticks([])
ax[7].set_yticks([])
ax[7].set_xlabel("Figure 6. Erythroblast")

fig.canvas.set_window_title("White blood cell types")

# %%
#Data Augmentation and creation of 
train_datagen = ImageDataGenerator(horizontal_flip=True, 
                                   vertical_flip=True,
                                   rotation_range=90,
                
                                   )
val_datagen   = ImageDataGenerator()

train_dataset = train_datagen.flow_from_directory(
    '/content/PBC_dataset_normal_DIB_pre/train',
    seed=777,
    target_size=(128, 128),
    batch_size=64,
    shuffle=True,
    class_mode = 'categorical')

val_dataset = val_datagen.flow_from_directory(
    '/content/PBC_dataset_normal_DIB_pre/val',
    seed=777,
    target_size=(128, 128),
    batch_size=64,
    shuffle=True,
    class_mode = 'categorical')
# Out:
# Found 11959 images belonging to 8 classes.
# Found 2561 images belonging to 8 classes.

# %%
img = load_img('PBC_dataset_normal_DIB/neutrophil/BNE_100878.jpg')
data = img_to_array(img)
# expand dimension to one sample
samples = expand_dims(data, 0)
# create image data augmentation generator
datagen = ImageDataGenerator(
                             horizontal_flip=True,
                             vertical_flip=True,
                             rotation_range=90
                             )
# prepare iterator
it = datagen.flow(samples, batch_size=1)
# generate samples and plot
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# generate batch of images
	batch = it.next()
	# convert to unsigned integers for viewing
	image = batch[0].astype('uint8')
  
	# plot raw pixel data
	plt.axis('off')
	plt.imshow(image)


# show the figure
plt.show()

# %%
class_dict = train_dataset.class_indices
print(class_dict)

x = type (train_dataset.num_classes)
print(x)
from collections import Counter

counter = Counter(train_dataset.classes)
counter1 = Counter(val_dataset.classes)
#counter2 = Counter(test_dataset.classes)

print(counter.items())
print(counter1.items())
#print(counter2.items())
# Out:
# {'basophil': 0, 'eosinophil': 1, 'erythroblast': 2, 'ig': 3, 'lymphocyte': 4, 'monocyte': 5, 'neutrophil': 6, 'platelet': 7}
# <class 'int'>
# dict_items([(0, 852), (1, 2181), (2, 1085), (3, 2026), (4, 849), (5, 993), (6, 2330), (7, 1643)])
# dict_items([(0, 182), (1, 467), (2, 232), (3, 434), (4, 182), (5, 213), (6, 499), (7, 352)])

# %%
#Show class distrubution in training data
c =sns.countplot(train_dataset.classes)
c.set_xlabel('Training data class distribution')
c.set_ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Count')

# %%
k=sns.countplot(val_dataset.classes)
k.set_xlabel('Validaion data class distribution')
k.set_ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'Count')

# %%
#model 

model2 = Sequential()
model2.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=(128,128,3),strides=1))
model2.add(MaxPooling2D(pool_size=(2, 2)))

model2.add(Conv2D(32, (3, 3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.2))

model2.add(Conv2D(64, (3, 3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.3))

model2.add(Conv2D(32, (3, 3), activation='relu'))
model2.add(MaxPooling2D(pool_size=(2, 2)))
model2.add(Dropout(0.4))

model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dense(80, activation='relu'))
model2.add(Dense(8, activation='softmax'))

# %%
model2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  dropout (Dropout)           (None, 30, 30, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 14, 14, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 32)        18464
#
#  max_pooling2d_3 (MaxPooling  (None, 6, 6, 32)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 32)          0
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dense (Dense)               (None, 128)               147584
#
#  dense_1 (Dense)             (None, 80)                10320
#
#  dense_2 (Dense)             (None, 8)                 648
#
# =================================================================
# Total params: 205,656
# Trainable params: 205,656
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Compile model
opt = keras.optimizers.Adam(learning_rate=0.001)
model2.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
#Reduce learning rate when validation accuracy not improving
learn_control = ReduceLROnPlateau(monitor='val_accuracy', patience=5,
                                  verbose=1,factor=0.2, min_lr=1e-9)

# %%
#Save model/weights in checkpoint file 
from keras.callbacks import Callback, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
filepath="modelbest.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# %%
#Fit model
model_fit = model2.fit(train_dataset,
                      steps_per_epoch = 100,  
                      validation_data=val_dataset,
                      epochs=50,
                      validation_steps = 28,
                      callbacks = [learn_control, checkpoint]
                      )

#Epochs
# Out:
# Epoch 1/50
# 100/100 [==============================] - ETA: 0s - loss: 4.5676 - accuracy: 0.2227
# Epoch 1: val_accuracy improved from -inf to 0.40458, saving model to modelbest.hdf5
# 100/100 [==============================] - 53s 400ms/step - loss: 4.5676 - accuracy: 0.2227 - val_loss: 1.6633 - val_accuracy: 0.4046 - lr: 0.0010
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 1.4172 - accuracy: 0.4467
# Epoch 2: val_accuracy improved from 0.40458 to 0.51674, saving model to modelbest.hdf5
# 100/100 [==============================] - 38s 384ms/step - loss: 1.4172 - accuracy: 0.4467 - val_loss: 1.2943 - val_accuracy: 0.5167 - lr: 0.0010
# Epoch 3/50
# 100/100 [==============================] - ETA: 0s - loss: 1.1087 - accuracy: 0.5821
# Epoch 3: val_accuracy improved from 0.51674 to 0.69587, saving model to modelbest.hdf5
# 100/100 [==============================] - 38s 377ms/step - loss: 1.1087 - accuracy: 0.5821 - val_loss: 0.8258 - val_accuracy: 0.6959 - lr: 0.0010
# Epoch 4/50
# 100/100 [==============================] - ETA: 0s - loss: 0.8635 - accuracy: 0.6803
# Epoch 4: val_accuracy improved from 0.69587 to 0.74386, saving model to modelbest.hdf5
# 100/100 [==============================] - 39s 390ms/step - loss: 0.8635 - accuracy: 0.6803 - val_loss: 0.6617 - val_accuracy: 0.7439 - lr: 0.0010
# Epoch 5/50
# 100/100 [==============================] - ETA: 0s - loss: 0.6985 - accuracy: 0.7340
# Epoch 5: val_accuracy did not improve from 0.74386
# 100/100 [==============================] - 38s 380ms/step - loss: 0.6985 - accuracy: 0.7340 - val_loss: 0.8464 - val_accuracy: 0.6512 - lr: 0.0010
# Epoch 6/50
# 100/100 [==============================] - ETA: 0s - loss: 0.6428 - accuracy: 0.7518
# Epoch 6: val_accuracy did not improve from 0.74386
# 100/100 [==============================] - 38s 379ms/step - loss: 0.6428 - accuracy: 0.7518 - val_loss: 0.6997 - val_accuracy: 0.7355 - lr: 0.0010
# Epoch 7/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5954 - accuracy: 0.7755
# Epoch 7: val_accuracy did not improve from 0.74386
# 100/100 [==============================] - 38s 375ms/step - loss: 0.5954 - accuracy: 0.7755 - val_loss: 0.6929 - val_accuracy: 0.7182 - lr: 0.0010
# Epoch 8/50
# 100/100 [==============================] - ETA: 0s - loss: 0.5547 - accuracy: 0.7935
# Epoch 8: val_accuracy improved from 0.74386 to 0.82199, saving model to modelbest.hdf5
# 100/100 [==============================] - 38s 378ms/step - loss: 0.5547 - accuracy: 0.7935 - val_loss: 0.4710 - val_accuracy: 0.8220 - lr: 0.0010
# Epoch 9/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4941 - accuracy: 0.8150
# Epoch 9: val_accuracy did not improve from 0.82199
# 100/100 [==============================] - 38s 378ms/step - loss: 0.4941 - accuracy: 0.8150 - val_loss: 0.5283 - val_accuracy: 0.7941 - lr: 0.0010
# Epoch 10/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.8179
# Epoch 10: val_accuracy improved from 0.82199 to 0.83426, saving model to modelbest.hdf5
# 100/100 [==============================] - 38s 379ms/step - loss: 0.4888 - accuracy: 0.8179 - val_loss: 0.4384 - val_accuracy: 0.8343 - lr: 0.0010
# Epoch 11/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.8256
# Epoch 11: val_accuracy improved from 0.83426 to 0.86607, saving model to modelbest.hdf5
# 100/100 [==============================] - 37s 374ms/step - loss: 0.4670 - accuracy: 0.8256 - val_loss: 0.3662 - val_accuracy: 0.8661 - lr: 0.0010
# Epoch 12/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4956 - accuracy: 0.8131
# Epoch 12: val_accuracy did not improve from 0.86607
# 100/100 [==============================] - 38s 375ms/step - loss: 0.4956 - accuracy: 0.8131 - val_loss: 0.5461 - val_accuracy: 0.7796 - lr: 0.0010
# Epoch 13/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4059 - accuracy: 0.8500
# Epoch 13: val_accuracy did not improve from 0.86607
# 100/100 [==============================] - 38s 379ms/step - loss: 0.4059 - accuracy: 0.8500 - val_loss: 0.4566 - val_accuracy: 0.8103 - lr: 0.0010
# Epoch 14/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4553 - accuracy: 0.8371
# Epoch 14: val_accuracy did not improve from 0.86607
# 100/100 [==============================] - 38s 380ms/step - loss: 0.4553 - accuracy: 0.8371 - val_loss: 0.4880 - val_accuracy: 0.8041 - lr: 0.0010
# Epoch 15/50
# 100/100 [==============================] - ETA: 0s - loss: 0.4090 - accuracy: 0.8438
# Epoch 15: val_accuracy did not improve from 0.86607
# 100/100 [==============================] - 38s 376ms/step - loss: 0.4090 - accuracy: 0.8438 - val_loss: 0.4374 - val_accuracy: 0.8292 - lr: 0.0010
# Epoch 16/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3780 - accuracy: 0.8622
# Epoch 16: val_accuracy improved from 0.86607 to 0.87165, saving model to modelbest.hdf5
# 100/100 [==============================] - 37s 375ms/step - loss: 0.3780 - accuracy: 0.8622 - val_loss: 0.3635 - val_accuracy: 0.8717 - lr: 0.0010
# Epoch 17/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.8619
# Epoch 17: val_accuracy did not improve from 0.87165
# 100/100 [==============================] - 37s 375ms/step - loss: 0.3746 - accuracy: 0.8619 - val_loss: 0.4692 - val_accuracy: 0.8225 - lr: 0.0010
# Epoch 18/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3634 - accuracy: 0.8715
# Epoch 18: val_accuracy improved from 0.87165 to 0.89286, saving model to modelbest.hdf5
# 100/100 [==============================] - 37s 374ms/step - loss: 0.3634 - accuracy: 0.8715 - val_loss: 0.3152 - val_accuracy: 0.8929 - lr: 0.0010
# Epoch 19/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3451 - accuracy: 0.8719
# Epoch 19: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 376ms/step - loss: 0.3451 - accuracy: 0.8719 - val_loss: 0.3792 - val_accuracy: 0.8577 - lr: 0.0010
# Epoch 20/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3205 - accuracy: 0.8825
# Epoch 20: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 375ms/step - loss: 0.3205 - accuracy: 0.8825 - val_loss: 0.3940 - val_accuracy: 0.8465 - lr: 0.0010
# Epoch 21/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.8797
# Epoch 21: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.3379 - accuracy: 0.8797 - val_loss: 0.5294 - val_accuracy: 0.7952 - lr: 0.0010
# Epoch 22/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8845
# Epoch 22: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 375ms/step - loss: 0.3207 - accuracy: 0.8845 - val_loss: 0.3013 - val_accuracy: 0.8923 - lr: 0.0010
# Epoch 23/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3269 - accuracy: 0.8806
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 23: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 375ms/step - loss: 0.3269 - accuracy: 0.8806 - val_loss: 0.3929 - val_accuracy: 0.8415 - lr: 0.0010
# Epoch 24/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9031
# Epoch 24: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 372ms/step - loss: 0.2725 - accuracy: 0.9031 - val_loss: 0.3104 - val_accuracy: 0.8850 - lr: 2.0000e-04
# Epoch 25/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2573 - accuracy: 0.9103
# Epoch 25: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2573 - accuracy: 0.9103 - val_loss: 0.3740 - val_accuracy: 0.8633 - lr: 2.0000e-04
# Epoch 26/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2466 - accuracy: 0.9152
# Epoch 26: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2466 - accuracy: 0.9152 - val_loss: 0.3262 - val_accuracy: 0.8817 - lr: 2.0000e-04
# Epoch 27/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9179
# Epoch 27: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 376ms/step - loss: 0.2346 - accuracy: 0.9179 - val_loss: 0.3670 - val_accuracy: 0.8689 - lr: 2.0000e-04
# Epoch 28/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2390 - accuracy: 0.9139
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 28: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2390 - accuracy: 0.9139 - val_loss: 0.4421 - val_accuracy: 0.8488 - lr: 2.0000e-04
# Epoch 29/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9205
# Epoch 29: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2283 - accuracy: 0.9205 - val_loss: 0.3730 - val_accuracy: 0.8638 - lr: 4.0000e-05
# Epoch 30/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.9260
# Epoch 30: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2259 - accuracy: 0.9260 - val_loss: 0.3799 - val_accuracy: 0.8627 - lr: 4.0000e-05
# Epoch 31/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.9167
# Epoch 31: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 373ms/step - loss: 0.2333 - accuracy: 0.9167 - val_loss: 0.3720 - val_accuracy: 0.8655 - lr: 4.0000e-05
# Epoch 32/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2290 - accuracy: 0.9227
# Epoch 32: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 373ms/step - loss: 0.2290 - accuracy: 0.9227 - val_loss: 0.3432 - val_accuracy: 0.8694 - lr: 4.0000e-05
# Epoch 33/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2277 - accuracy: 0.9233
# Epoch 33: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 33: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 372ms/step - loss: 0.2277 - accuracy: 0.9233 - val_loss: 0.3915 - val_accuracy: 0.8599 - lr: 4.0000e-05
# Epoch 34/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9242
# Epoch 34: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 371ms/step - loss: 0.2136 - accuracy: 0.9242 - val_loss: 0.3524 - val_accuracy: 0.8733 - lr: 8.0000e-06
# Epoch 35/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.9212
# Epoch 35: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2266 - accuracy: 0.9212 - val_loss: 0.3668 - val_accuracy: 0.8683 - lr: 8.0000e-06
# Epoch 36/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9204
# Epoch 36: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 370ms/step - loss: 0.2287 - accuracy: 0.9204 - val_loss: 0.3892 - val_accuracy: 0.8633 - lr: 8.0000e-06
# Epoch 37/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9249
# Epoch 37: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2183 - accuracy: 0.9249 - val_loss: 0.3488 - val_accuracy: 0.8722 - lr: 8.0000e-06
# Epoch 38/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9238
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 38: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 374ms/step - loss: 0.2283 - accuracy: 0.9238 - val_loss: 0.3931 - val_accuracy: 0.8610 - lr: 8.0000e-06
# Epoch 39/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2200 - accuracy: 0.9225
# Epoch 39: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 372ms/step - loss: 0.2200 - accuracy: 0.9225 - val_loss: 0.3873 - val_accuracy: 0.8605 - lr: 1.6000e-06
# Epoch 40/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2135 - accuracy: 0.9236
# Epoch 40: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 371ms/step - loss: 0.2135 - accuracy: 0.9236 - val_loss: 0.3566 - val_accuracy: 0.8717 - lr: 1.6000e-06
# Epoch 41/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9236
# Epoch 41: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 373ms/step - loss: 0.2273 - accuracy: 0.9236 - val_loss: 0.3681 - val_accuracy: 0.8627 - lr: 1.6000e-06
# Epoch 42/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2168 - accuracy: 0.9243
# Epoch 42: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 37s 371ms/step - loss: 0.2168 - accuracy: 0.9243 - val_loss: 0.3615 - val_accuracy: 0.8677 - lr: 1.6000e-06
# Epoch 43/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2228 - accuracy: 0.9249
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
#
# Epoch 43: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 382ms/step - loss: 0.2228 - accuracy: 0.9249 - val_loss: 0.3580 - val_accuracy: 0.8705 - lr: 1.6000e-06
# Epoch 44/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2317 - accuracy: 0.9158
# Epoch 44: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 382ms/step - loss: 0.2317 - accuracy: 0.9158 - val_loss: 0.3645 - val_accuracy: 0.8633 - lr: 3.2000e-07
# Epoch 45/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2181 - accuracy: 0.9244
# Epoch 45: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 382ms/step - loss: 0.2181 - accuracy: 0.9244 - val_loss: 0.3614 - val_accuracy: 0.8683 - lr: 3.2000e-07
# Epoch 46/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9217
# Epoch 46: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 382ms/step - loss: 0.2204 - accuracy: 0.9217 - val_loss: 0.3577 - val_accuracy: 0.8689 - lr: 3.2000e-07
# Epoch 47/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2265 - accuracy: 0.9217
# Epoch 47: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 40s 405ms/step - loss: 0.2265 - accuracy: 0.9217 - val_loss: 0.3570 - val_accuracy: 0.8700 - lr: 3.2000e-07
# Epoch 48/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2155 - accuracy: 0.9233
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
#
# Epoch 48: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 377ms/step - loss: 0.2155 - accuracy: 0.9233 - val_loss: 0.3572 - val_accuracy: 0.8705 - lr: 3.2000e-07
# Epoch 49/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2256 - accuracy: 0.9214
# Epoch 49: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 380ms/step - loss: 0.2256 - accuracy: 0.9214 - val_loss: 0.3882 - val_accuracy: 0.8644 - lr: 6.4000e-08
# Epoch 50/50
# 100/100 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9192
# Epoch 50: val_accuracy did not improve from 0.89286
# 100/100 [==============================] - 38s 376ms/step - loss: 0.2338 - accuracy: 0.9192 - val_loss: 0.3698 - val_accuracy: 0.8650 - lr: 6.4000e-08

# %%
 #keras.backend.clear_session() # Use this function to clear any prevuiusly stored model data

# %%
# Function for plotting

def show_final_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    ax[0].set_title('Loss')
    ax[0].plot(history.epoch, history.history["loss"], label="Train loss")
    ax[0].plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax[1].set_title('Accuracy')
    ax[1].plot(history.epoch, history.history["accuracy"], label="Train acc")
    ax[1].plot(history.epoch, history.history["val_accuracy"], label="Validation acc")
    ax[0].legend()
    ax[1].legend()

# %%
#Show learning curve
show_final_history(model_fit)

# %%
#Create and augment test data
test_datagen   = ImageDataGenerator()
test_dataset = test_datagen.flow_from_directory(
    '/content/PBC_dataset_normal_DIB_pre/test',
    seed=777,
    target_size=(128, 128),
    batch_size=64,
    class_mode = 'categorical')
# Out:
# Found 2572 images belonging to 8 classes.

# %%
#Calculate test steps
test_steps = test_dataset.n // test_dataset.batch_size
print(test_steps)
# Out:
# 40

# %%
#Evaluate test model performance
valid_loss, valid_accuracy = model2.evaluate(val_dataset)
test_loss, test_accuracy   = model2.evaluate(test_dataset)
# Out:
# 41/41 [==============================] - 5s 129ms/step - loss: 0.3730 - accuracy: 0.8645
# 41/41 [==============================] - 5s 129ms/step - loss: 0.3868 - accuracy: 0.8631

# %%
print('Validation Accuracy: ', round((valid_accuracy * 100), 1), "%")
print('Test Accuracy: ', round((test_accuracy * 100), 1), "%")
print(" ")
print('Validation Loss: ', round(valid_loss, 1))
print('Test Loss: ', round(test_loss, 1))
# Out:
# Validation Accuracy:  86.5 %
# Test Accuracy:  86.3 %
#
# Validation Loss:  0.4
# Test Loss:  0.4

# %%
test_dataset.reset()
X_test_, y_test_true = [],[] 
for i in range(test_steps):
    X , y = next(test_dataset)
    X_test_.extend(X) 
    y_test_true.extend(y)

# %%
#Convert to numpy arrays
X_test_    = np.array(X_test_)
y_test_true= np.array(y_test_true)
print(X_test_.shape, y_test_true.shape)
# Out:
# (2560, 128, 128, 3) (2560, 8)

# %%
#Predict using model2
y_pred = model2.predict(X_test_)

# %%
#Setting figure size for confusion matrix
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
#Plot confusion matrix
confusionMatrix = confusion_matrix(np.argmax(y_test_true, axis=1), np.argmax(y_pred, axis=1))

ax = sns.heatmap(confusionMatrix, annot=True, cmap='Blues',fmt='g')

ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Blood Cells Category')
ax.set_ylabel('Actual Blood Cells Category ');

# ax.xaxis.set_ticklabels(classes)
# ax.yaxis.set_ticklabels(classes)

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
#Print Classification report
print(classification_report(np.argmax(y_test_true, axis=1), np.argmax(y_pred, axis=1),zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.99      0.72       183
#            1       0.99      0.97      0.98       466
#            2       0.96      0.83      0.89       234
#            3       0.70      0.66      0.68       434
#            4       0.96      0.74      0.83       182
#            5       0.98      0.56      0.71       212
#            6       0.88      0.99      0.93       500
#            7       0.99      0.99      0.99       349
#
#     accuracy                           0.86      2560
#    macro avg       0.88      0.84      0.84      2560
# weighted avg       0.88      0.86      0.86      2560

# %%
#Plot sample of predicted classes 
fig, axes = plt.subplots(nrows=3, ncols=5, figsize=(20, 10),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
  ax.imshow((X_test_[i]).astype('uint8'))
  ax.set_title(f"True: {list(test_dataset.class_indices.keys())[list(test_dataset.class_indices.values()).index(np.argmax(y_test_true, axis=1)[i])]}\nPredicted: {list(test_dataset.class_indices.keys())[list(test_dataset.class_indices.values()).index(np.argmax(y_pred, axis=1)[i])]}")
plt.tight_layout()
plt.show();
